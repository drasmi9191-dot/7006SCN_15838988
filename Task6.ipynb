# %%
from PIL import Image
import matplotlib.pyplot as plt

# Path to the selected image
img_path = '/content/Data Quality and Pipeline Monitoring.png'

# Open and display the image
img = Image.open(img_path)
plt.figure(figsize=(15, 15))
plt.imshow(img)
plt.axis('off')  # Hide axes
plt.show()

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Path to the selected image
img_path = '/content/Model Performance and Feature Importance.png'

# Open and display the image
img = Image.open(img_path)
plt.figure(figsize=(15, 15))
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Path to the selected image
img_path = '/content/Business Insights.png'

# Open and display the image
img = Image.open(img_path)
plt.figure(figsize=(15, 15))
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Path to the selected image
img_path = '/content/Scalability and Cost Analysis.png'

# Open and display the image
img = Image.open(img_path)
plt.figure(figsize=(15, 15))
plt.imshow(img)
plt.axis('off')
plt.show()
